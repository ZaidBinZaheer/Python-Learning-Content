# %%
import os
import pandas as pd

# %%
# load planes_features data
planes = pd.read_csv('Dataset_FlightRadar24_1.csv')
planes
# Out:
#        Flight_ID       From       To   Timestamp                   UTC  \
# 0              1  Islamabad    Dubai  1715574293  2024-05-13T04:24:53Z
# 1              1  Islamabad    Dubai  1715574309  2024-05-13T04:25:09Z
# 2              1  Islamabad    Dubai  1715574324  2024-05-13T04:25:24Z
# 3              1  Islamabad    Dubai  1715574340  2024-05-13T04:25:40Z
# 4              1  Islamabad    Dubai  1715574361  2024-05-13T04:26:01Z
# ...          ...        ...      ...         ...                   ...
# 19920         38    El Paso  El Paso  1715834792  2024-05-16T04:46:32Z
# 19921         38    El Paso  El Paso  1715834801  2024-05-16T04:46:41Z
# 19922         38    El Paso  El Paso  1715834804  2024-05-16T04:46:44Z
# 19923         38    El Paso  El Paso  1715834807  2024-05-16T04:46:47Z
# 19924         38    El Paso  El Paso  1715834812  2024-05-16T04:46:52Z
#
#       Callsign               Position  Altitude  Speed  Direction     Class
# ...

# %%
planes['Time'] = planes['UTC'].str[11:19]
planes
# Out:
#        Flight_ID       From       To   Timestamp                   UTC  \
# 0              1  Islamabad    Dubai  1715574293  2024-05-13T04:24:53Z
# 1              1  Islamabad    Dubai  1715574309  2024-05-13T04:25:09Z
# 2              1  Islamabad    Dubai  1715574324  2024-05-13T04:25:24Z
# 3              1  Islamabad    Dubai  1715574340  2024-05-13T04:25:40Z
# 4              1  Islamabad    Dubai  1715574361  2024-05-13T04:26:01Z
# ...          ...        ...      ...         ...                   ...
# 19920         38    El Paso  El Paso  1715834792  2024-05-16T04:46:32Z
# 19921         38    El Paso  El Paso  1715834801  2024-05-16T04:46:41Z
# 19922         38    El Paso  El Paso  1715834804  2024-05-16T04:46:44Z
# 19923         38    El Paso  El Paso  1715834807  2024-05-16T04:46:47Z
# 19924         38    El Paso  El Paso  1715834812  2024-05-16T04:46:52Z
#
#       Callsign               Position  Altitude  Speed  Direction     Class  \
# ...

# %% [markdown]
# ##### Grouping data based on Flight_ID

# %%
grouped = planes.groupby('Flight_ID')

# %%
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# Plot using matplotlib
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot altitude on the first y-axis (blue)
ax1.plot(planes['Time'], planes['Altitude'], color='blue', marker='o', linestyle='-', label='Altitude')
ax1.set_xlabel('Time')
ax1.set_ylabel('Altitude', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a second y-axis for speed (green)
ax2 = ax1.twinx()
ax2.plot(planes['Time'], planes['Speed'], color='green', marker='s', linestyle='-', label='Speed')
ax2.set_ylabel('Speed', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title('Altitude and Speed vs. Time')
plt.show()

# %%
# Group the dataset by 'Flight_ID'
# grouped = planes.groupby('Flight_ID')

# Iterate over each group
for flight_id, group_data in grouped:
    print(f"Flight ID: {flight_id}")
    # print(group_data.head())  



    # Plot using matplotlib
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Plot altitude on the first y-axis (blue)
    ax1.plot(group_data['Time'], group_data['Altitude'], color='blue', marker='o', linestyle='-', label='Altitude')
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Altitude', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Create a second y-axis for speed (green)
    ax2 = ax1.twinx()
    ax2.plot(group_data['Time'], group_data['Speed'], color='green', marker='s', linestyle='-', label='Speed')
    ax2.set_ylabel('Speed', color='green')
    ax2.tick_params(axis='y', labelcolor='green')

    # Add legend
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

    plt.title('Altitude and Speed vs. Time')
    plt.show()
# Out:
# Flight ID: 1
# Flight ID: 2
# Flight ID: 3
# Flight ID: 4
# Flight ID: 5
# Flight ID: 6
# Flight ID: 7
# Flight ID: 8
# Flight ID: 9
# Flight ID: 10
# Flight ID: 11
# Flight ID: 12
# Flight ID: 13
# Flight ID: 14
# Flight ID: 15
# Flight ID: 16
# Flight ID: 17
# Flight ID: 18
# Flight ID: 19
# Flight ID: 20
# Flight ID: 21
# Flight ID: 22
# Flight ID: 23
# Flight ID: 24
# Flight ID: 25
# Flight ID: 26
# Flight ID: 27
# Flight ID: 28
# Flight ID: 29
# Flight ID: 30
# Flight ID: 31
# Flight ID: 32
# Flight ID: 33
# Flight ID: 34
# Flight ID: 35
# Flight ID: 36
# Flight ID: 37
# Flight ID: 38
